# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.Loan_ID.value_counts(dropna=False)
# Out:
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: Loan_ID, Length: 614, dtype: int64

# %%
df.Gender.value_counts(dropna=False)
# Out:
# Male      489
# Female    112
# NaN        13
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Gender',data=df)
plt.show()

# %%
countmale=len(df[df.Gender=='Male'])
countfemale=len(df[df.Gender=='Female'])
countnull=len(df[df.Gender.isnull()])
print("print Male percentage {:.2f}%".format(countmale/len(df.Gender)*100))
print(" print Female percentage {:.2f}%".format(countfemale/len(df.Gender)*100))
print("Total Null vales {:.2f}%".format(countnull/len(df.Gender)*100))
# Out:
# print Male percentage 79.64%
#  print Female percentage 18.24%
# Total Null vales 2.12%

# %%
df.Married.value_counts(dropna=False)
# Out:
# Yes    398
# No     213
# NaN      3
# Name: Married, dtype: int64

# %%
married=len(df[df.Married=='Yes'])
notmarried=len(df[df.Married=='No'])
notnull=len(df[df.Married.isnull()])
print ('Married {:.2f}%' . format(married/len(df.Married)*100))
print (' Not Married {:.2f}%'.format(notmarried/len(df.Married)*100))
print('The null vales are{:.2f}%'.format((notnull/len(df.Married)*100)))
# Out:
# Married 64.82%
#  Not Married 34.69%
# The null vales are0.49%

# %%
df.Education.value_counts(dropna=False)
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
graduate=len(df[df.Education=='Graduate'])
notgraduate=len(df[df.Education=='Not Graduate'])
nul=len(df[df.Education.isnull()])

# %%
df.Self_Employed.value_counts(dropna=False)
# Out:
# No     500
# Yes     82
# NaN     32
# Name: Self_Employed, dtype: int64

# %%
employed=len(df[df.Self_Employed=='Yes'])
notemployed=len(df[df.Self_Employed=='No'])
nill=len(df[df.Self_Employed.isnull()])

# %%
df.Credit_History.value_counts(dropna=False)
# Out:
# 1.0    475
# 0.0     89
# NaN     50
# Name: Credit_History, dtype: int64

# %%
history=len(df[df.Credit_History==1])
nohistory=len(df[df.Credit_History==0])
ntg=len(df[df.Credit_History.isnull()])

# %%
df.Property_Area.value_counts(dropna=False)
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
urban=len(df[df.Property_Area=='Urban'])
rural=len(df[df.Property_Area=='Rural'])
prona=len(df[df.Property_Area.isnull()])

# %%
df.Credit_History.value_counts(dropna=False)
# Out:
# 1.0    475
# 0.0     89
# NaN     50
# Name: Credit_History, dtype: int64

# %%
df.Loan_Status.value_counts(dropna=False)
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
cn=len(df[df.Loan_Status=='Y'])
cn=len(df[df.Loan_Status=='N'])
cnn=len(df[df.Loan_Status.isnull()])

# %%
df.Loan_Amount_Term.value_counts(dropna=False)
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# NaN       14
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %% [markdown]
# # Numerical values

# %%
df[['ApplicantIncome','CoapplicantIncome','LoanAmount']].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       614.000000         614.000000  592.000000
# mean       5403.459283        1621.245798  146.412162
# std        6109.041673        2926.248369   85.587325
# min         150.000000           0.000000    9.000000
# 25%        2877.500000           0.000000  100.000000
# 50%        3812.500000        1188.500000  128.000000
# 75%        5795.000000        2297.250000  168.000000
# max       81000.000000       41667.000000  700.000000

# %% [markdown]
# # Distribution of numerical value

# %% [markdown]
#  Histrogram distribution

# %%
sns.set(style='darkgrid')
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x='ApplicantIncome',kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x='CoapplicantIncome',kde=True,ax=axs[0,1],color='skyblue')
sns.histplot(data=df,x='LoanAmount',kde=True,ax=axs[1,0],color='orange')
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Count'>

# %% [markdown]
# viloin plot

# %%
sns.set(style='darkgrid')
fig,axs1=plt.subplots(2,2,figsize=(10,10))
sns.violinplot(data=df,y='ApplicantIncome',ax=axs1[0,0],color='green')
sns.violinplot(data=df,y='CoapplicantIncome',ax=axs1[0,1],color='skyblue')
sns.violinplot(data=df,y='LoanAmount',ax=axs1[1,0],color='orange')
# Out:
# <AxesSubplot:ylabel='LoanAmount'>

# %% [markdown]
# other exploration

# %%
plt.figure(figsize=[12,9])
sns.heatmap(df.corr(),annot=True,cmap='hsv')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # categorical

# %%
pd.crosstab(df.Gender,df.Married).plot(kind='bar',stacked=True,figsize=(5,5))
plt.xticks(rotation=0)
plt.show()

# %%
pd.crosstab(df.Self_Employed,df.Credit_History).plot(kind='bar',figsize=(4,4),stacked=True)
plt.xticks(rotation=0)
plt.show()

# %%
pd.crosstab(df.Property_Area,df.Loan_Status).plot(kind='bar',stacked=True,figsize=(5,5))
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# catergorical numberical

# %%
sns.boxplot(x='Loan_Status',y='ApplicantIncome',data=df,palette='PuBuGn')
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.boxplot(data=df,x='CoapplicantIncome',y='Loan_Status',palette='YlOrRd_r')
# Out:
# <AxesSubplot:xlabel='CoapplicantIncome', ylabel='Loan_Status'>

# %%
sns.boxplot(x='Loan_Status',y='LoanAmount',data=df,palette='flare')
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='LoanAmount'>

# %% [markdown]
# # Numerical

# %%
import scipy.stats as stats
df.plot(x='ApplicantIncome',y='CoapplicantIncome',style='o')
plt.show()
print('Pearson correlation',df['ApplicantIncome'].corr(df['CoapplicantIncome']))
print('t test and p value :\n ', stats.ttest_ind(df['ApplicantIncome'],df['CoapplicantIncome']))
# Out:
# Pearson correlation -0.11660458122889966
# t test and p value :
#   Ttest_indResult(statistic=13.835753259915665, pvalue=1.460983948423972e-40)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
df=df.drop(['Loan_ID'],axis=1)

# %% [markdown]
# Data imputation

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Married'].fillna(df['Married'].mode()[0],inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0],inplace=True)

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(),inplace=True)

# %% [markdown]
# # One Hot Encoding

# %%
df=pd.get_dummies(df)
df=df.drop(['Gender_Female','Married_No','Education_Not Graduate','Self_Employed_No','Loan_Status_N'],axis=1)
new={'Gender_Male':'Gender','Married_Yes':'Married','Education_Graduate':'Education','Self_Employed_Yes':'Self_Employed','Loan_Status_Y':'Loan_Status'}
df.rename(columns=new,inplace=True)

# %% [markdown]
# # Remove Outliers and Infinite values

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
iqr=q3-q1
df=df[~((df<(q1-1.5*iqr))|(df>(q3+1.5*iqr))).any(axis=1)]

# %% [markdown]
# # Skewed Distribution Treatment

# %%
df.ApplicantIncome=np.sqrt(df.ApplicantIncome)
df.CoapplicantIncome=np.sqrt(df.CoapplicantIncome)
df.LoanAmount=np.sqrt(df.LoanAmount)

# %%
sns.set(style='darkgrid')
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x='ApplicantIncome',kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x='CoapplicantIncome',kde=True,ax=axs[0,1],color='skyblue')
sns.histplot(data=df,x='LoanAmount',kde=True,ax=axs[1,0],color='orange')
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Count'>

# %% [markdown]
# # Feature Separating

# %%
x=df.drop(['Loan_Status'],axis=1)
y=df['Loan_Status']

# %% [markdown]
# # Smote  Technique

# %%
from imblearn.over_sampling  import SMOTE
x,y=SMOTE().fit_resample(x,y)

# %%
sns.set_theme(style='darkgrid')
sns.countplot(y=y,data=df)
plt.show()

# %% [markdown]
# # Data Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
x=MinMaxScaler().fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split


lr=LogisticRegression(solver='saga',max_iter=500,random_state=1)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=500, random_state=1, solver='saga')

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import accuracy_score
LRAcc=accuracy_score(y_pred,y_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print('LR Accuracy :{:.2f}%'. format(LRAcc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        23
#            1       0.90      0.82      0.86        22
#
#     accuracy                           0.87        45
#    macro avg       0.87      0.87      0.87        45
# weighted avg       0.87      0.87      0.87        45
#
# [[21  2]
#  [ 4 18]]
# LR Accuracy :86.67%

# %% [markdown]
# # K - Nearst Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier
scorelistknn=[]
for i in range(1,21):
    KNclassifier=KNeighborsClassifier(n_neighbors=i)
    KNclassifier.fit(x_train,y_train)
    scorelistknn.append(KNclassifier.score(x_test,y_test))
plt.plot(range(1,21),scorelistknn) 
plt.xticks(np.arange(1,21,1))
plt.show()
KNAcc=max(scorelistknn)

# %% [markdown]
# # Support vector Machine

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf',max_iter=500)
svc.fit(x_train,y_train)
# Out:
# SVC(max_iter=500)

# %%
y_pred=svc.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
from sklearn.metrics import accuracy_score
svcacc=accuracy_score(y_pred,y_test)
print(' SVC  Acuuracy :{:.2f}%'.format(svcacc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        23
#            1       0.91      0.95      0.93        22
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45
#
# [[21  2]
#  [ 1 21]]
#  SVC  Acuuracy :93.33%

# %% [markdown]
# # Navie Bayes

# %%
from sklearn.naive_bayes import CategoricalNB
nb=CategoricalNB()
nb.fit(x_train,y_train)
y_pred=nb.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
from sklearn.metrics import accuracy_score
nbacc1=accuracy_score(y_pred,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.74        23
#            1       0.72      0.82      0.77        22
#
#     accuracy                           0.76        45
#    macro avg       0.76      0.76      0.76        45
# weighted avg       0.76      0.76      0.75        45
#
# [[16  7]
#  [ 4 18]]

# %%
from sklearn.naive_bayes import GaussianNB
nbc=GaussianNB()
nbc.fit(x_train,y_train)
y_pred=nbc.predict(x_test)
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
nbacc2=accuracy_score(y_pred,y_test)
print('Gaussian navie bayes accuarcy :{:.2f}%'.format(nbacc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74        23
#            1       0.73      0.73      0.73        22
#
#     accuracy                           0.73        45
#    macro avg       0.73      0.73      0.73        45
# weighted avg       0.73      0.73      0.73        45
#
# [[17  6]
#  [ 6 16]]
# Gaussian navie bayes accuarcy :73.33%

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier 
scorek=[]
for i in range(2,21):
    dt=DecisionTreeClassifier(max_leaf_nodes=i)
    dt.fit(x_train,y_train)
    scorek.append(dt.score(x_test,y_test))
plt.plot(range(2,21),scorek) 
plt.xticks(np.arange(2,21,1))
plt.show()
dtacc=max(scorek)
print('Decision Tree Accuracty :{:.2f}%'.format(dtacc*100))
# Out:
# Decision Tree Accuracty :80.00%

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rc=[]
for i in range(2,25):
    rfc=RandomForestClassifier(n_estimators=100,random_state=1,max_leaf_nodes=i)
    rfc.fit(x_train,y_train)
    rc.append(rfc.score(x_test,y_test))
    
plt.plot(range(2,25),rc)
plt.xticks(np.arange(2,25,1))
plt.show()
rfacc=max(rc)
print ( ' Randm Forest Accuracy :{:.2F}%'.format(rfacc*100))
# Out:
#  Randm Forest Accuracy :93.33%

# %% [markdown]
# # Gradient Boosting

# %%
paramsgb={'n_estimators':[50,100,150],'learning_rate':[0.01,0.1,0.5],'max_depth':[3,4,5]}

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

gb = RandomizedSearchCV(GradientBoostingClassifier(), paramsgb, cv=20)
gb.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=20, estimator=GradientBoostingClassifier(),
#                    param_distributions={'learning_rate': [0.01, 0.1, 0.5],
#                                         'max_depth': [3, 4, 5],
#                                         'n_estimators': [50, 100, 150]})

# %%
print(gb.best_estimator_)
print(gb.best_score_)
print(gb.best_params_)
print(gb.best_index_)
# Out:
# GradientBoostingClassifier(max_depth=4, n_estimators=150)
# 0.8277777777777777
# {'n_estimators': 150, 'max_depth': 4, 'learning_rate': 0.1}
# 1

# %%
gbc=GradientBoostingClassifier(subsample=0.5,n_estimators=150,max_depth=4,learning_rate=0.1)
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=4, n_estimators=150, subsample=0.5)

# %%
y_pred=gbc.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
gbacc=accuracy_score(y_pred,y_test)
print('Gradient boosting accuracy :{:.2F}%'.format(gbacc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.86        23
#            1       0.94      0.73      0.82        22
#
#     accuracy                           0.84        45
#    macro avg       0.86      0.84      0.84        45
# weighted avg       0.86      0.84      0.84        45
#
# [[22  1]
#  [ 6 16]]
# Gradient boosting accuracy :84.44%

# %%
compare=pd.DataFrame({'model ':['Logistic Regression ','K neighbors','SVM','Categorical NB','Gaussian NB','Decision Tree','Random Forest','Gradient Boost'],'Accuracy':[LRAcc*100,KNAcc*100,svcacc*100,nbacc1*100,nbacc2*100,dtacc*100,rfacc*100,gbacc*100]})

# %%
compare.sort_values(by='Accuracy',ascending=False)
# Out:
#                  model    Accuracy
# 1           K neighbors  93.333333
# 2                   SVM  93.333333
# 6         Random Forest  93.333333
# 0  Logistic Regression   86.666667
# 7        Gradient Boost  84.444444
# 5         Decision Tree  80.000000
# 3        Categorical NB  75.555556
# 4           Gaussian NB  73.333333

# %%
import os
if not os.path.exists('model'):
    os.makedirs('model')

# %%
import pickle

# %% [markdown]
# # conclusion

# %%
from sklearn.neighbors import KNeighborsClassifier
KNAcc=KNeighborsClassifier()
KNAcc.fit(x_train,y_train)
filename='model/Loan1.pkl'
with open(filename,'wb') as file:
    pickle.dump(KNAcc,file)
load_model=pickle.load(open(filename,'rb'))  
result=load_model.score(x_test,y_test)
print(result*100)
# Out:
# 88.88888888888889

# %% [markdown]
# * imported the Required libraries
# *Checked for null values
# * Checked the percentage ratio of the each column to understand the dataset
# * checked the numerical values
# * checked the distrivution for the numerical values by using dist and voilin plot
# * checked the distribution on the categorical dataset by using countplot , boxplot and scatterplot
# * we did data preprocessing and data imputation
# * did one hot encoding on the datasets and removed the outliers in the dataframe
# * checked for the skewed distribution and removed the skweness
# * separated the data and used smote techinique to balance the data
# * Did data normalization and imported the models
# * splited the data into train and test split
# * used different models like , Random forest , Gradiant booster , Knn , Support vector ,Decision tree and navie byes
# * checked the each model performance using the heatmap and line plots
# * we have saved the model using the pickle method and we got good accuarcy by the model using the KNN neighbors
# * We did cros validation on the model it gave good accuarcy
