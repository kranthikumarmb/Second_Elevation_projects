# %%
import pandas as pd
import numpy as  np 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# # Descriptive analysis

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
print('Rows:{} columns:{}'.format(df.shape[0],df.shape[1]))
# Out:
# Rows:32560 columns:15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# statistical summary 
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %%
# check for the null values 
round((df.isnull().sum()/df.shape[0]) * 100 , 2).astype(str)+ '%'
# Out:
# Age               0.0%
# Workclass         0.0%
# Fnlwgt            0.0%
# Education         0.0%
# Education_num     0.0%
# Marital_status    0.0%
# Occupation        0.0%
# Relationship      0.0%
# Race              0.0%
# Sex               0.0%
# Capital_gain      0.0%
# Capital_loss      0.0%
# Hours_per_week    0.0%
# Native_country    0.0%
# Income            0.0%
# dtype: object

# %%
round((df.isin(['?']).sum()/df.shape[0])*100,2).astype(str)+'%'
# Out:
# Age               0.0%
# Workclass         0.0%
# Fnlwgt            0.0%
# Education         0.0%
# Education_num     0.0%
# Marital_status    0.0%
# Occupation        0.0%
# Relationship      0.0%
# Race              0.0%
# Sex               0.0%
# Capital_gain      0.0%
# Capital_loss      0.0%
# Hours_per_week    0.0%
# Native_country    0.0%
# Income            0.0%
# dtype: object

# %%
# checking the label categories 
income=df['Income'].value_counts(normalize=True)
round(income*100,2).astype('str')+'%'
# Out:
#  <=50K    75.92%
#  >50K     24.08%
# Name: Income, dtype: object

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Univariate analysis

# %%
import warnings
warnings.filterwarnings('ignore')
income=df['Income'].value_counts()
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(7,5))
sns.barplot(income.index,income.values)
plt.title('Distribution of income', fontdict={'fontname':'Monospace','fontsize':20,'fontweight':'bold'})
plt.xlabel('Income',fontdict={'fontname':'monospace','fontsize':9})
plt.ylabel('Number of People ' ,fontdict={'fontname':'Monospace','fontsize':12})
plt.tick_params(labelsize=10)
plt.show()

# %%
age=df['Age'].value_counts()
plt.style.use('fivethirtyeight')
sns.distplot(df['Age'],bins=20)
plt.title('Distribution of Age',fontdict={'fontname':'Monospace','fontsize':12,'fontweight':'bold'})
plt.xlabel('Age',fontdict={'fontname':'Monospace','fontsize':12})
plt.ylabel('Number of People')
plt.tick_params(labelsize=10)
plt.show()

# %%
ed=df['Education_num'].value_counts()
plt.figure(figsize=(12,6))
sns.set_style('whitegrid')
sns.barplot(x=ed.values,y=ed.index,palette='pastel')
plt.title('Years of education')
plt.ylabel('Years of education',fontdict={'fontname':'Arial'})
plt.xlabel('Number of People ',fontdict={'fontname':'Verdana'})
plt.tick_params(axis='both',which='major',labelsize=12,colors='black',direction='out',length=6,width=2)
plt.show()

# %%
# creating a pie  chart for  Marital status
mar=df['Marital_status'].value_counts()
plt.style.use('bmh')
plt.pie(mar.values,labels=mar.index,startangle=10,explode=(0,0.20,0,0,0,0,0),shadow=True,autopct='%1.1f%%')
plt.legend()
plt.legend(prop={'size':7})
plt.axis('equal')
plt.show()

# %%
# creating a donut chart for 'Age'
relation=df['Relationship'].value_counts()
plt.style.use('ggplot')
plt.figure(figsize=(8,7))
plt.pie(relation.values,labels=relation.index,startangle=50,autopct='%1.1f%%')
centre_circle=plt.Circle((0,0),0.7,fc='white')
fig=plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Relationship Distribution ', fontdict={'fontname':'Monospace','fontsize':30,'fontweight':'bold'})
plt.axis('equal')
plt.legend(prop={'size':9})
plt.show()

# %%
# creating a bar plot for Sex
sex=df['Sex'].value_counts()
plt.style.use('default')
plt.figure(figsize=(6,5))
sns.barplot(sex.index,sex.values)
plt.title('Dustribution of sex')
plt.xlabel('Sex')
plt.ylabel('Number of people')
plt.tick_params(labelsize=10)
plt.grid()
plt.show()

# %%
# !pip install squarify
import squarify

# %%
race=df['Race'].value_counts()
plt.style.use('seaborn')
plt.figure(figsize=(7,5))
squarify.plot(sizes=race.values,label=race.index,value=race.values)
plt.title('Race distribution')
plt.show()

# %%
# creating a bar plot ' hours per week '
hou=df['Hours_per_week'].value_counts().head(10)
plt.style.use('tableau-colorblind10')
sns.barplot(hou.index,hou.values,palette='husl')
plt.title('Distribution of working hours in week')
plt.xlabel('Hours of work ')
plt.ylabel('Number of people')

plt.show()

# %% [markdown]
# # Bivariant analysis

# %%
cat_col=df.dtypes[df.dtypes=='object']
num_col=df.dtypes[df.dtypes!='object']

# %%
for col in list(cat_col.index):
    print(f"----------{col.title()}----------")
    total=df[col].value_counts()
    percent=df[col].value_counts()/ df.shape[0]
    df1=pd.concat([total,percent],keys=['total','percent'],axis=1)
    print(df1)
    print('\n')
# Out:
# ----------Workclass----------
#                    total   percent
#  Private           22696  0.697052
#  Self-emp-not-inc   2541  0.078041
#  Local-gov          2093  0.064281
#  ?                  1836  0.056388
#  State-gov          1297  0.039834
#  Self-emp-inc       1116  0.034275
#  Federal-gov         960  0.029484
#  Without-pay          14  0.000430
#  Never-worked          7  0.000215
#
#
# ----------Education----------
#                total   percent
#  HS-grad       10501  0.322512
#  Some-college   7291  0.223925
#  Bachelors      5354  0.164435
#  Masters        1723  0.052918
#  Assoc-voc      1382  0.042445
#  11th           1175  0.036087
#  Assoc-acdm     1067  0.032770
#  10th            933  0.028655
#  7th-8th         646  0.019840
#  Prof-school     576  0.017690
#  9th             514  0.015786
#  12th            433  0.013299
#  Doctorate       413  0.012684
#  5th-6th         333  0.010227
#  1st-4th         168  0.005160
#  Preschool        51  0.001566
# ...

# %%
table_occu=pd.crosstab(df['Occupation'],df['Income'])
table_workclass=pd.crosstab(df['Workclass'],df['Income'])
table_edu=pd.crosstab(df['Education'],df['Income'])
table_marital=pd.crosstab(df['Marital_status'],df['Income'])
table_race=pd.crosstab(df['Race'],df['Income'])
table_sex=pd.crosstab(df['Sex'],df['Income'])
table_country=pd.crosstab(df['Native_country'],df['Income'])

# %%
fig=plt.figure(figsize=(12,4))
ax=fig.add_subplot(1,2,1)
table_occu.div(table_occu.sum(axis=1), axis=0).plot(kind='bar',stacked=True,ax=ax)
plt.xlabel('occuaption')
plt.ylabel('Proportion of people')
# Out:
# Text(0, 0.5, 'Proportion of people')

# %% [markdown]
# # Multivariate analysis

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
sns.pairplot(df)
plt.show()

# %%
corr=df.corr()

# %%
mask=np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
with sns.axes_style('white'):
    f,ax=plt.subplots(figsize=(7,4))
    ax=sns.heatmap(corr,mask=mask,vmax=.3,square=True,annot=True,cmap='RdYlGn')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
df=df.replace('?',np.nan)

# %%
round((df.isnull().sum()/df.shape[0]) * 100, 2).astype(str) +'%'
# Out:
# Age               0.0%
# Workclass         0.0%
# Fnlwgt            0.0%
# Education         0.0%
# Education_num     0.0%
# Marital_status    0.0%
# Occupation        0.0%
# Relationship      0.0%
# Race              0.0%
# Sex               0.0%
# Capital_gain      0.0%
# Capital_loss      0.0%
# Hours_per_week    0.0%
# Native_country    0.0%
# Income            0.0%
# dtype: object

# %% [markdown]
# # Label encoding

# %%
for col in df.columns:
    if df[col].dtypes=='object':
        encoder=LabelEncoder()
        df[col]=encoder.fit_transform(df[col])

# %% [markdown]
# # Feature selection

# %%
x=df.drop('Income',axis=1)
y=df['Income']

# %%
from sklearn.ensemble import ExtraTreesClassifier
selector=ExtraTreesClassifier(random_state=42)

# %%
selector.fit(x,y)
# Out:
# ExtraTreesClassifier(random_state=42)

# %%
feature_imp=selector.feature_importances_

# %%
for index, val in enumerate(feature_imp):
    print(index,round(val * 100),2)
# Out:
# 0 15 2
# 1 4 2
# 2 17 2
# 3 4 2
# 4 9 2
# 5 7 2
# 6 7 2
# 7 9 2
# 8 1 2
# 9 3 2
# 10 9 2
# 11 3 2
# 12 9 2
# 13 2 2

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  int32
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  int32
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  int32
#  6   Occupation      32560 non-null  int32
#  7   Relationship    32560 non-null  int32
#  8   Race            32560 non-null  int32
#  9   Sex             32560 non-null  int32
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  int32
# dtypes: int32(8), int64(6)
# memory usage: 2.5 MB

# %%
x=x.drop(['Workclass','Education','Race','Sex','Capital_loss','Native_country'],axis=1)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
for col in x.columns:
    scaler=StandardScaler()
    x[col]=scaler.fit_transform(x[col].values.reshape(-1,1))

# %% [markdown]
# # Fixing the imbalance data

# %%
round(y.value_counts(normalize=True) * 100, 2).astype('str') + '%'
# Out:
# 0    75.92%
# 1    24.08%
# Name: Income, dtype: object

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros=RandomOverSampler()

# %%
ros.fit(x,y)
# Out:
# RandomOverSampler()

# %%
x_resampled,y_resampled=ros.fit_resample(x,y)

# %%
round(y_resampled.value_counts(normalize=True) * 100, 2).astype('str') + '%'
# Out:
# 0    50.0%
# 1    50.0%
# Name: Income, dtype: object

# %% [markdown]
# # Creating train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_resampled,y_resampled,test_size=0.2,random_state=42)

# %%
print(" X_train shape", x_train.shape)
print('y_train shape',y_train.shape)
print('x_test shape',x_test.shape)
print('y_test shape' , y_test.shape)
# Out:
#  X_train shape (39550, 8)
# y_train shape (39550,)
# x_test shape (9888, 8)
# y_test shape (9888,)

# %% [markdown]
# # Data Modelling

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log=log_reg.predict(x_test)

# %% [markdown]
# # KNN Clasifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(x_test)

# %% [markdown]
# # Support vector classifier

# %%
from sklearn.svm import SVC

# %%
svc=SVC(random_state=42)
svc.fit(x_train,y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred_svc=svc.predict(x_test)

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb=nb.predict(x_test)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dec_tree=DecisionTreeClassifier()
dec_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dec=dec_tree.predict(x_test)

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier()

# %%
ran.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_ran=ran.predict(x_test)

# %% [markdown]
# # XGB Classifier

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred_xgb=xgb.predict(x_test)

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred_log)

# %%
plt.style.use('default')
sns.heatmap(cm,annot=True,fmt='d',cmap='gist_rainbow')
plt.savefig('Heatmap.png')
plt.show()

# %%
print('Logistic Regression')
print('Accuracy score', round(accuracy_score(y_test,y_pred_log)*100 , 2))
print('f1 _ score :', round(f1_score(y_test,y_pred_log)*100 , 2))
# Out:
# Logistic Regression
# Accuracy score 76.69
# f1 _ score : 76.75

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.77      4943
#            1       0.77      0.77      0.77      4945
#
#     accuracy                           0.77      9888
#    macro avg       0.77      0.77      0.77      9888
# weighted avg       0.77      0.77      0.77      9888

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred_knn)

# %%
plt.style.use('default')
sns.heatmap(cm,annot=True,fmt='d',cmap='gist_rainbow')
plt.savefig('Heatmap.png')
plt.show()

# %%
print('KNN Clasifier')
print('Accuracy Score',round(accuracy_score(y_test,y_pred_knn)*100 , 2))
print('f1_score',round(f1_score(y_test,y_pred_knn)*100 , 2))
# Out:
# KNN Clasifier
# Accuracy Score 83.74
# f1_score 84.76

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83      4943
#            1       0.80      0.90      0.85      4945
#
#     accuracy                           0.84      9888
#    macro avg       0.84      0.84      0.84      9888
# weighted avg       0.84      0.84      0.84      9888

# %%
cm=confusion_matrix(y_test,y_pred_svc)
plt.style.use('default')
sns.heatmap(cm,annot=True,fmt='d',cmap='tab10')
plt.savefig('Heatmap.png')
plt.show()

# %%
print('Support Vector Classifier')
print('Accurcay_score', round(accuracy_score(y_test,y_pred_svc)*100 , 2))
print('f1 score' , round(f1_score(y_test,y_pred_svc)*100 , 2))
# Out:
# Support Vector Classifier
# Accurcay_score 82.23
# f1 score 83.31

# %%
print(classification_report(y_test,y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81      4943
#            1       0.79      0.89      0.83      4945
#
#     accuracy                           0.82      9888
#    macro avg       0.83      0.82      0.82      9888
# weighted avg       0.83      0.82      0.82      9888

# %%
cm=confusion_matrix(y_test,y_pred_nb)
plt.style.use('ggplot')
sns.heatmap(cm,annot=True,cmap='winter_r',fmt='d')
plt.savefig('Heatmap.png')
plt.show()

# %%
print('Navie Byes')
print('Accuracy_score',round(accuracy_score(y_test,y_pred_nb)*100 , 2))
print(' F1 score',round(f1_score(y_test,y_pred_nb)*100 , 2))
# Out:
# Navie Byes
# Accuracy_score 66.75
#  F1 score 53.1

# %%
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.96      0.74      4943
#            1       0.90      0.38      0.53      4945
#
#     accuracy                           0.67      9888
#    macro avg       0.75      0.67      0.64      9888
# weighted avg       0.75      0.67      0.64      9888

# %%
cm=confusion_matrix(y_test,y_pred_dec)
plt.style.use('default')
sns.heatmap(cm,annot=True,cmap='BuGn',fmt='d')
plt.savefig('Heatmap.png')
plt.show()

# %%
print('Decision Tree Classifier')
print('Accuracy score',round(accuracy_score(y_test,y_pred_dec)*100 , 2))
print('f1 score',round(f1_score(y_test,y_pred_dec)*100 , 2))
# Out:
# Decision Tree Classifier
# Accuracy score 91.25
# f1 score 91.74

# %%
print(classification_report(y_test,y_pred_dec))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      4943
#            1       0.87      0.97      0.92      4945
#
#     accuracy                           0.91      9888
#    macro avg       0.92      0.91      0.91      9888
# weighted avg       0.92      0.91      0.91      9888

# %%
cm=confusion_matrix(y_test,y_pred_ran)
plt.style.use('default')
sns.heatmap(cm,fmt='d',cmap='vlag_r',annot=True)
plt.savefig('Heatmap.png')
plt.show()

# %%
print('Random Forest')
print('Accuracy_score',round(accuracy_score(y_test,y_pred_ran)*100 , 2))
print('F1 score',round(f1_score(y_test,y_pred_ran)*100 , 2))
# Out:
# Random Forest
# Accuracy_score 92.61
# F1 score 92.96

# %%
cm=confusion_matrix(y_test,y_pred_xgb)
plt.style.use('ggplot')
sns.heatmap(cm, cmap='flare_r',fmt='d',annot=True)
plt.savefig('Heatmap.png')
plt.show()

# %%
print('XGB Classifier')
print('Accuracy score',round(accuracy_score(y_test,y_pred_xgb)*100 , 2))
print('F1 score',round(f1_score(y_test,y_pred_xgb)*100 , 2))
# Out:
# XGB Classifier
# Accuracy score 86.36
# F1 score 86.94

# %%
print(classification_report(y_test,y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      4943
#            1       0.83      0.91      0.87      4945
#
#     accuracy                           0.86      9888
#    macro avg       0.87      0.86      0.86      9888
# weighted avg       0.87      0.86      0.86      9888

# %% [markdown]
# Out of all models Random Forest Classifier gives good accuracy

# %% [markdown]
# # Hyperparameter Tunning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
rf=RandomForestClassifier(random_state=42)

# %%
param_grid={'n_estimators':[100,200,300],'max_depth':[None,5,10],'min_samples_split':[2,5,10],'min_samples_leaf':[1,2,4],'max_features':['auto','sqrt']}

# %%
rf_cv=RandomizedSearchCV(rf,param_grid,cv=5)

# %%
rf_cv.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#                    param_distributions={'max_depth': [None, 5, 10],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]})

# %%
rf_cv.best_score_
# Out:
# 0.902654867256637

# %%
rf_cv.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': None}

# %%
rf_best=RandomForestClassifier(max_depth=102,n_estimators=40,random_state=42)

# %%
rf_best.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=102, n_estimators=40, random_state=42)

# %%
y_pred_rf_best=rf_best.predict(x_test)

# %%
print('Random Forest Classifier')
print('Accurcy score', round(accuracy_score(y_test,y_pred_rf_best)*100 , 2))
print('f1 score',round(f1_score(y_test,y_pred_rf_best)*100 , 2))
# Out:
# Random Forest Classifier
# Accurcy score 92.43
# f1 score 92.79

# %%
from sklearn.metrics import confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred_rf_best)

# %%
plt.style.use('default')
sns.heatmap(cm,annot=True,fmt='d',cmap='Accent')
plt.savefig('heatmap.png')
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_rf_best))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92      4943
#            1       0.89      0.98      0.93      4945
#
#     accuracy                           0.92      9888
#    macro avg       0.93      0.92      0.92      9888
# weighted avg       0.93      0.92      0.92      9888

# %% [markdown]
# # Conculsion

# %% [raw]
# * imported the necessray libraries
# * did statistical summary
# * checked the null values
# * we used different visulization concept like baox , scatter, pie, center circle to the data flow.
# * did multivariate analysis
# * chcked the correlation nbetween the columns witrh the help of heatmap
# *  did data preprocessing
# * we did label encoding  and feature selection on the data set
# * made feature scaling and and fixed tge imbalance data
# * careted train and test data
# * used the logistic regresion operation on the dataset
# * we used different functions like Random forest , KNN classifier , XGBoost , Decision Tree, support Vector classifier
# * we did hyper parameter tunning and checked the best accauracy score of the each model and saved them by using the pickle method and checkd the cross validation of the data
# * we Saved the random forest classifier for the model hemce it is giving us the good accuracy
